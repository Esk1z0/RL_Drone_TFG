# %% [markdown]
# {
#   "reward_curriculum": [
#     {
#       "reward_function": {
#         "name": "Bioloid_Reward_Hyperparameters_ajustment",
#         "info": "This json contains the hyperparameters for the test number 1",
#         "final_reward": 100,
#         "command": 0,
#         "max_time": 120,
#         "tests": [
#           {
#             "name": "no_roll",
#             "parameters": {
#               "max_angle": 180,
#               "max_reward": 0.01
#             }
#           },
#           {
#             "name": "forward_distance",
#             "parameters": {
#               "scale": 1.0
#             }
#           },
#           {
#             "name": "motor_inactivity_penalty",
#             "parameters": {
#               "penalty": -0.2,
#               "max_inactive_steps": 10.0,
#               "threshold_total": 0.1
#             }
#           }
#         ]
#       }
#     }
#   ]
# }

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./data/case1_results.csv")

# %%
df.head()
# Out:
#    rollout/ep_len_mean  time/fps  time/iterations  rollout/ep_rew_mean  \
# 0             8.571429         1                1            -1.560203
# 1             8.793103         1                2            -1.602031
# 2             8.173913         1                3            -1.473652
# 3             8.000000         1                4            -1.434865
# 4             8.000000         1                5            -1.430593
#
#    time/total_timesteps  time/time_elapsed  train/std  train/learning_rate  \
# 0                   128                 81        NaN                  NaN
# 1                   256                153   1.001206                0.001
# 2                   384                241   0.999500                0.001
# 3                   512                320   0.999657                0.001
# 4                   640                397   1.000879                0.001
#
#    train/explained_variance  train/entropy_loss  train/value_loss  \
# ...

# %%
sns.lineplot(data=df["rollout/ep_rew_mean"])
# Out:
# <Axes: ylabel='rollout/ep_rew_mean'>

# %%
sns.lineplot(data=df["rollout/ep_len_mean"])
# Out:
# <Axes: ylabel='rollout/ep_len_mean'>
